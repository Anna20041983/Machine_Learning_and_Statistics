# %%
# Data frames
import pandas as pd

# Shuffle
import random

#Statistics
import scipy.stats as ss
from scipy.stats.contingency import crosstab

# %% [markdown]
# ### Chi-Square Tests

# %% [markdown]
# #### Laerd Statistics Chi-Square Test for Independence
# https://statistics.laerd.com/spss-tutorials/chi-square-test-for-association-using-spss-statistics.php

# %%
# Sixteen Males who preferred Books

male_books = [['Male', 'Books']] * 16

# Show

male_books
# Out:
# [['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books']]

# %%
# Theerteen Females who preferred Books

female_books = [['Female', 'Books']] * 13

# Show

female_books
# Out:
# [['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books']]

# %%
# Twenty-four Males who preferred Online

male_online = [['Male', 'Online']] * 24

# Show

male_online
# Out:
# [['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online']]

# %%
# Twenty-seven Females who preferred Online

female_online = [['Female', 'Online']] * 27

# Show

female_online
# Out:
# [['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online']]

# %%
# Raw data, merge the four lists

raw_data = male_books + male_online + female_books + female_online

# Show

raw_data
# Out:
# [['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online']]

# %%
# Shuffle the data

random.shuffle(raw_data)

# Show

raw_data
# Out:
# [['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Female', 'Online'],
#  ['Male', 'Books'],
#  ['Female', 'Books'],
#  ['Male', 'Online'],
#  ['Male', 'Books'],
#  ['Male', 'Books'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Male', 'Books'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Male', 'Books'],
#  ['Female', 'Online'],
#  ['Female', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Online'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Male', 'Online'],
#  ['Female', 'Books'],
#  ['Female', 'Books'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Male', 'Books'],
#  ['Male', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online'],
#  ['Female', 'Online']]

# %%
# Zip the list - make the rows columns and the columns rows
# Interchganges the outer and inner lists

gender, medium = list(zip(*raw_data))

# Show

gender, medium
# Out:
# (('Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female'),
#  ('Books',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Books',
#   'Books',
#   'Books',
#   'Online',
#   'Books',
#   'Books',
#   'Online',
#   'Books',
#   'Books',
#   'Books',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Books',
#   'Books',
#   'Online',
#   'Books',
#   'Books',
#   'Online',
#   'Books',
#   'Online',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Books',
#   'Online',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Online',
#   'Online',
#   'Books',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Books',
#   'Online',
#   'Online',
#   'Online',
#   'Online',
#   'Online'))

# %%
# Create a data frame

df = pd.DataFrame({'gender': gender, 'medium': medium})

# Show

df
# Out:
#     gender  medium
# 0     Male   Books
# 1     Male   Books
# 2     Male  Online
# 3   Female  Online
# 4   Female  Online
# ..     ...     ...
# 75    Male  Online
# 76  Female  Online
# 77  Female  Online
# 78  Female  Online
# 79  Female  Online
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Contingency Table

# %%
# Perform Crosstabs Contingency
cross = ss.contingency.crosstab(df['gender'], df['medium'])

# Show
cross
# Out:
# CrosstabResult(elements=(array(['Female', 'Male'], dtype=object), array(['Books', 'Online'], dtype=object)), count=array([[13, 27],
#        [16, 24]]))

# %%
# The first variable values and the second
first, second = cross.elements

# Show
first, second
# Out:
# (array(['Female', 'Male'], dtype=object),
#  array(['Books', 'Online'], dtype=object))

# %%
# The counts
cross.count
# Out:
# array([[13, 27],
#        [16, 24]])

# %%
# Find all rows in df with gender equal to the first value in first
df[df['gender'] == first[0]]
# Out:
#     gender  medium
# 3   Female  Online
# 4   Female  Online
# 5   Female  Online
# 6   Female  Online
# 8   Female   Books
# 9   Female  Online
# 12  Female  Online
# 14  Female  Online
# 18  Female   Books
# 20  Female   Books
# 22  Female  Online
# 24  Female   Books
# 28  Female   Books
# 31  Female  Online
# 32  Female  Online
# 35  Female   Books
# 38  Female  Online
# 39  Female  Online
# 42  Female   Books
# 43  Female   Books
# 46  Female   Books
# 52  Female  Online
# 53  Female  Online
# 54  Female  Online
# 55  Female  Online
# 56  Female  Online
# 57  Female  Online
# 59  Female   Books
# 61  Female  Online
# 62  Female   Books
# 64  Female  Online
# 69  Female   Books
# 70  Female   Books
# 71  Female  Online
# 72  Female  Online
# 73  Female  Online
# 76  Female  Online
# 77  Female  Online
# 78  Female  Online
# 79  Female  Online

# %%
# Find all rows in df with gender equal to the first value in first and medium equal to first value in second
df[df['gender'] == first[0]][df['medium'] == second[0]]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_36844\4290009448.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['gender'] == first[0]][df['medium'] == second[0]]
#     gender medium
# 8   Female  Books
# 18  Female  Books
# 20  Female  Books
# 24  Female  Books
# 28  Female  Books
# 35  Female  Books
# 42  Female  Books
# 43  Female  Books
# 46  Female  Books
# 59  Female  Books
# 62  Female  Books
# 69  Female  Books
# 70  Female  Books

# %%
# The contingency table
cross.count
# Out:
# array([[13, 27],
#        [16, 24]])

# %%
# Do the statistics
result = ss.chi2_contingency(cross.count, correction = False)

# Show
result
# Out:
# Chi2ContingencyResult(statistic=0.486815415821501, pvalue=0.4853513240525321, dof=1, expected_freq=array([[14.5, 25.5],
#        [14.5, 25.5]]))

# %%
# The expected frequencies if independent
result.expected_freq
# Out:
# array([[14.5, 25.5],
#        [14.5, 25.5]])

# %%
# Preffered books irrespective of gender
29 / 80
# Out:
# 0.3625

# %% [markdown]
# ***
# End
